# %%
import pandas as pd

# %% [markdown]
# ### Load in data

# %%
df = pd.read_csv("matpor_concat.csv", delimiter=',')

# %%
df.head()
# Out:
#    Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu     Mjob  \
# 0           0     GP   F   18       U     GT3       A     4     4  at_home
# 1           1     GP   F   17       U     GT3       T     1     1  at_home
# 2           2     GP   F   15       U     LE3       T     1     1  at_home
# 3           3     GP   F   15       U     GT3       T     4     2   health
# 4           4     GP   F   16       U     GT3       T     3     3    other
#
#     ...   freetime goout Dalc  Walc  health  absences  G1  G2  G3 subject
# 0   ...          3     4    1     1       3         6   5   6   6       M
# 1   ...          3     3    1     1       3         4   5   5   6       M
# 2   ...          3     2    2     3       3        10   7   8  10       M
# 3   ...          2     2    1     1       5         2  15  14  15       M
# 4   ...          3     2    1     2       5         4   6  10  10       M
#
# [5 rows x 35 columns]

# %% [markdown]
# ## PgmPy

# %%
from statsmodels.formula.api import ols
result = ols(formula="G3 ~ freetime + studytime + schoolsup + paid + failures + famsup + absences + health + subject", data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     G3   R-squared:                       0.195
# Model:                            OLS   Adj. R-squared:                  0.188
# Method:                 Least Squares   F-statistic:                     27.81
# Date:                Thu, 18 Oct 2018   Prob (F-statistic):           1.98e-43
# Time:                        12:02:56   Log-Likelihood:                -2779.1
# No. Observations:                1044   AIC:                             5578.
# Df Residuals:                    1034   BIC:                             5628.
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
